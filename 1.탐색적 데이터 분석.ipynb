# %% [markdown]
# #**스마트폰 센서 데이터 기반 모션 분류**
# # 단계1 : 탐색적 데이터 분석

# %% [markdown]
# ## 0.미션

# %% [markdown]
# ### (1) 미션1
# 수많은 feature들을 모두 살펴보는 것은 과도한 시간과 노력이 필요합니다. 그래서 여러분은 **선택과 집중**을 해야 합니다.
# * 1) **기본 모델을 생성**한 후 **변수 중요도**를 구합니다.
#     * random forest 알고리즘 사용을 권장합니다.
# * 2) **중요한 feature와 중요하지 않은 feature 상위 N개를 선정**하고, 이들을 대상으로 EDA 수행.

# %% [markdown]
# ### (2) 미션2
# 다음의 case에 맞게 feature 및 feature 그룹 중요도를 기반으로 탐색적 데이터 분석을 수행하시오.
# * Target을 **정적/동적 행동**으로 구분
#     * 6개의 행동은 2개의 그룹(정적행동, 동적행동)으로 나뉩니다.
#     * 어떤 feature(혹은 feature 그룹)이 2개 class 그룹(정적행동, 동적행동)를 구분하는데 중요한지를 찾아보고 탐색해봅시다.

# %% [markdown]
# ## 1.환경설정

# %% [markdown]
# * 세부 요구사항
#     - 경로 설정 : 구글콜랩
#         * 구글 드라이브 바로 밑에 project1 폴더를 만들고,
#         * 데이터 파일을 복사해 넣습니다.
#     - 기본적으로 필요한 라이브러리를 import 하도록 코드가 작성되어 있습니다.
#         * 필요하다고 판단되는 라이브러리를 추가하세요.

# %% [markdown]
# ### (1) 경로 설정

# %% [markdown]
# * 구글 드라이브 연결

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/project1_2/'

# %% [markdown]
# ### (2) 라이브러리 설치 및 불러오기

# %% [markdown]
# * 라이브러리 로딩
#     - pandas, numpy,matplotlib,seaborn, joblib 을 로딩하고
#     필요한 라이브러리를 로딩합니다.
#     <br>(분류 모델에서는 이번에 RandomForestClassifier를 씁니다. 더 많은 분류 모델을 써도 됩니다!)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import joblib

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report

# %% [markdown]
# * 제공 함수 생성
#     * 변수 중요도를 시각화할 수 있는 함수를 제공합니다.
#     * 입력 :
#         * importance : 트리모델의 변수 중요도(예: model.feature_importances_)
#         * names : 변수 이름 목록(예 : x_train.columns)
#         * result_only  : 변수 중요도 순으로 데이터프레임만 return할지, 그래프도 포함할지 결정. False이면 결과 데이터프레임 + 그래프
#         * topn : 중요도 상위 n개만 표시. all 이면 전체.
#     * 출력 :
#         * 중요도 그래프 : 중요도 내림차순으로 정렬
#         * 중요도 데이터프레임 : 중요도 내림차순으로 정렬

# %%
# 변수의 특성 중요도 계산하기
def plot_feature_importance(importance, names, result_only = False, topn = 'all'):
    feature_importance = np.array(importance)
    feature_name = np.array(names)

    data={'feature_name':feature_name,'feature_importance':feature_importance}
    fi_temp = pd.DataFrame(data)

    #변수의 특성 중요도 순으로 정렬하기
    fi_temp.sort_values(by=['feature_importance'], ascending=False,inplace=True)
    fi_temp.reset_index(drop=True, inplace = True)

    if topn == 'all' :
        fi_df = fi_temp.copy()
    else :
        fi_df = fi_temp.iloc[:topn]

    #변수의 특성 중요도 그래프로 그리기
    if result_only == False :
        plt.figure(figsize=(10,20))
        sns.barplot(x='feature_importance', y='feature_name', data = fi_df)

        plt.xlabel('importance')
        plt.ylabel('feature name')
        plt.grid()

    return fi_df

# %% [markdown]
# ### (3) 데이터 불러오기

# %% [markdown]
# * 주어진 데이터셋
#     * data01_train.csv : 학습 및 검증용
#     * data01_test.csv : 테스트용
#     * feature.csv : feature 이름을 계층구조로 정리한 데이터
#
# * 세부 요구사항
#     * 칼럼 삭제 : data01_train.csv와 data01_test.csv 에서 'subject' 칼럼은 불필요하므로 삭제합니다.

# %%
# 주어진 데이터 셋을 불러오세요.
train = pd.read_csv(path + 'data01_train.csv')
test = pd.read_csv(path + 'data01_test.csv')

# %%
#불필요한 칼럼을 삭제하세요.
train = train.drop('subject', axis = 1)
test = test.drop('subject', axis = 1)

# %% [markdown]
# ## 2.데이터 분석 : 기본정보 살펴보기

# %% [markdown]
# ### (1) 기본정보 확인하기

# %% [markdown]
# * **세부 요구사항**
#     - 불러온 데이터의 형태, 기초통계량, 정보 등을 확인합니다.

# %%
# 전체 데이터의 행, 열 개수를 확인
print(train.shape)
print(test.shape)
# Out:
# (5881, 562)
# (1471, 562)

# %%
# 전체 데이터의 상위 5개 행 확인
train.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.288508          -0.009196          -0.103362         -0.988986
# 1           0.265757          -0.016576          -0.098163         -0.989551
# 2           0.278709          -0.014511          -0.108717         -0.997720
# 3           0.289795          -0.035536          -0.150354         -0.231727
# 4           0.394807           0.034098           0.091229          0.088489
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.962797         -0.967422         -0.989000         -0.962596
# 1         -0.994636         -0.987435         -0.990189         -0.993870
# 2         -0.981088         -0.994008         -0.997934         -0.982187
# 3         -0.006412         -0.338117         -0.273557          0.014245
# 4         -0.106636         -0.388502         -0.010469         -0.109680
#
# ...

# %%
test.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.284379          -0.021981          -0.116683         -0.992490
# 1           0.277440          -0.028086          -0.118412         -0.996620
# 2           0.305833          -0.041023          -0.087303          0.006880
# 3           0.276053          -0.016487          -0.108381         -0.995379
# 4           0.271998           0.016904          -0.078856         -0.973468
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.979640         -0.963321         -0.992563         -0.977304
# 1         -0.927676         -0.972294         -0.997346         -0.931405
# 2          0.182800         -0.237984          0.005642          0.028616
# 3         -0.983978         -0.975854         -0.995877         -0.985280
# 4         -0.702462         -0.869450         -0.979810         -0.711601
#
# ...

# %%
# 전체 데이터의 수치형 변수 분포 확인
train.describe()
# Out:
#        tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# count        5881.000000        5881.000000        5881.000000
# mean            0.274811          -0.017799          -0.109396
# std             0.067614           0.039422           0.058373
# min            -0.503823          -0.684893          -1.000000
# 25%             0.262919          -0.024877          -0.121051
# 50%             0.277154          -0.017221          -0.108781
# 75%             0.288526          -0.010920          -0.098163
# max             1.000000           1.000000           1.000000
#
#        tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# count       5881.000000       5881.000000       5881.000000       5881.000000
# mean          -0.603138         -0.509815         -0.604058         -0.628151
# std            0.448807          0.501815          0.417319          0.424345
# min           -1.000000         -0.999844         -0.999667         -1.000000
# ...

# %%
test.describe()
# Out:
#        tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# count        1471.000000        1471.000000        1471.000000
# mean            0.273198          -0.017281          -0.108123
# std             0.079989           0.045957           0.049082
# min            -1.000000          -1.000000          -0.418354
# 25%             0.263787          -0.024792          -0.120733
# 50%             0.277322          -0.017187          -0.108124
# 75%             0.288058          -0.010238          -0.096606
# max             0.631510           0.359587           0.543939
#
#        tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# count       1471.000000       1471.000000       1471.000000       1471.000000
# mean          -0.614634         -0.515427         -0.607533         -0.639950
# std            0.448480          0.506094          0.424243          0.422994
# min           -0.999717         -0.999873         -1.000000         -0.999867
# ...

# %%
#전체 데이터의 모든 변수 확인
train.columns
# Out:
# Index(['tBodyAcc-mean()-X', 'tBodyAcc-mean()-Y', 'tBodyAcc-mean()-Z',
#        'tBodyAcc-std()-X', 'tBodyAcc-std()-Y', 'tBodyAcc-std()-Z',
#        'tBodyAcc-mad()-X', 'tBodyAcc-mad()-Y', 'tBodyAcc-mad()-Z',
#        'tBodyAcc-max()-X',
#        ...
#        'fBodyBodyGyroJerkMag-skewness()', 'fBodyBodyGyroJerkMag-kurtosis()',
#        'angle(tBodyAccMean,gravity)', 'angle(tBodyAccJerkMean),gravityMean)',
#        'angle(tBodyGyroMean,gravityMean)',
#        'angle(tBodyGyroJerkMean,gravityMean)', 'angle(X,gravityMean)',
#        'angle(Y,gravityMean)', 'angle(Z,gravityMean)', 'Activity'],
#       dtype='object', length=562)

# %%
#(추가) 다양하게 기본 정보들을 확인하세요!

# %% [markdown]
# ### (2) 목표 변수 확인하기

# %% [markdown]
# * **세부 요구사항**
#     - target인 'Activity'에 대해 단변량 분석을 수행합니다.
#     - 범주의 종류, 범주별 빈도수 및 비율 등

# %%
# Activity 에 대해서 단변량 분석을 시행합니다. (범주별 빈도수, 종류, 비율, 시각화도 해보기!)

# %%
train['Activity'].value_counts()
# Out:
# Activity
# LAYING                1115
# STANDING              1087
# SITTING               1032
# WALKING                998
# WALKING_UPSTAIRS       858
# WALKING_DOWNSTAIRS     791
# Name: count, dtype: int64

# %%
train['Activity'].value_counts(normalize=True)
# Out:
# Activity
# LAYING                0.189594
# STANDING              0.184833
# SITTING               0.175480
# WALKING               0.169699
# WALKING_UPSTAIRS      0.145894
# WALKING_DOWNSTAIRS    0.134501
# Name: proportion, dtype: float64

# %%
test['Activity'].value_counts()
# Out:
# Activity
# LAYING                292
# STANDING              287
# SITTING               254
# WALKING               228
# WALKING_UPSTAIRS      215
# WALKING_DOWNSTAIRS    195
# Name: count, dtype: int64

# %%
test['Activity'].value_counts(normalize=True)
# Out:
# Activity
# LAYING                0.198504
# STANDING              0.195105
# SITTING               0.172672
# WALKING               0.154997
# WALKING_UPSTAIRS      0.146159
# WALKING_DOWNSTAIRS    0.132563
# Name: proportion, dtype: float64

# %%
order = train['Activity'].value_counts().index
palette = sns.color_palette("viridis", len(order))

plt.figure(figsize=(12, 4))
sns.countplot(
    data=train,
    x='Activity',
    order=order,
    palette=palette
)
plt.show()
# Out:
# /tmp/ipython-input-3962865203.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(

# %%
order = test['Activity'].value_counts().index
palette = sns.color_palette("viridis", len(order))

plt.figure(figsize=(12, 4))
sns.countplot(
    data=test,
    x='Activity',
    order=order,
    palette=palette
)
plt.show()
# Out:
# /tmp/ipython-input-478631890.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(

# %% [markdown]
# ### (3) 센서 그룹 데이터: features

# %% [markdown]
# * **세부 요구사항**
#     - feature 이름에 대한 계층 구조별로 변수의 수를 카운트 해 봅시다.
#         - sensor 별 변수의 개수
#         - agg(regation) 별 변수의 개수
#         - axis 별 변수의 개수

# %%
features = pd.read_csv(path + 'features.csv')

# %%
#센서 그룹 데이터의 'sensor'변수의 값 확인
features['sensor'].value_counts()
# Out:
# sensor
# fBodyGyro               79
# fBodyAccJerk            79
# fBodyAcc                79
# tBodyAcc                40
# tGravityAcc             40
# tBodyAccJerk            40
# tBodyGyroJerk           40
# tBodyGyro               40
# tGravityAccMag          13
# tBodyAccMag             13
# tBodyGyroJerkMag        13
# tBodyGyroMag            13
# tBodyAccJerkMag         13
# fBodyAccMag             13
# fBodyBodyAccJerkMag     13
# fBodyBodyGyroMag        13
# fBodyBodyGyroJerkMag    13
# angle                    7
# Name: count, dtype: int64

# %%
#센서 그룹 데이터의 'agg'변수의 값 확인
features['agg'].value_counts()
# Out:
# agg
# bandsEnergy()        126
# arCoeff()             60
# std()                 33
# mad()                 33
# max()                 33
# energy()              33
# min()                 33
# entropy()             33
# iqr()                 33
# mean()                33
# sma()                 17
# correlation()         15
# kurtosis()            13
# meanFreq()            13
# skewness()            13
# maxInds               13
# arCoeff()4             5
# arCoeff()2             5
# arCoeff()3             5
# arCoeff()1             5
# tBodyAccMean           1
# tBodyAccJerkMean       1
# tBodyGyroMean          1
# tBodyGyroJerkMean      1
# X                      1
# Y                      1
# Z                      1
# Name: count, dtype: int64

# %%
#센서 그룹 데이터의 'axis'변수의 값 확인
features['axis'].value_counts()
# Out:
# axis
# X              76
# Y              76
# Z              76
# gravityMean     6
# X,2             5
#                ..
# 17,32.2         2
# 49,64.2         2
# 1,24.2          2
# 25,48.2         2
# gravity         1
# Name: count, Length: 62, dtype: int64

# %% [markdown]
# ## 3.미션1 : 데이터 분석1

# %% [markdown]
# 수많은 feature들을 모두 살펴보는 것은 과도한 시간과 노력이 필요합니다. 그래서 여러분은 **선택과 집중**을 해야 합니다.
# * 1) **트리 모델을 생성**한 후 **변수 중요도**를 구합니다.
#     * random forest 알고리즘 사용을 권장합니다.
# * 2) **중요한 feature 상위 N개를 선정**하고, 이들을 대상으로 EDA 수행.
# * 3) **각 feature 그룹별 중요도**도 파악해보며 EDA를 수행
#     * Feature 이름에는 계층구조를 담고 있습니다. 그렇다 보니 feature들을 적절하게 그룹으로 묶을 수 있습니다.
#     * 참고로, feature 그룹의 중요도는 개별 feature 중요도의 합으로 계산할 수 있습니다.

# %% [markdown]
# ### (1) 기본모델링 + 변수중요도 추출

# %% [markdown]
# * **세부 요구사항**
#     - 모델링을 위한 기본 전처리를 수행합니다.
#         - 주어진 데이터에서는 x, y로 나누고 train과 validation 분할 수행
#     - 트리기반 알고리즘을 이용하여 모델링을 합니다.
#         - 랜덤포레스트 권장 : 랜덤포레스트는 튜닝 없이 하이퍼파리미터의 기본값로도 적절한 성능의 모델을 생성할 수 있습니다.
#     - 변수 중요도 추출
#         - 사용자정의함수로 생성한 plot_feature_importance 을 이용
#         - 변수중요도 파악및 결과 저장

# %% [markdown]
# #### 1) 데이터 전처리

# %%
# 데이터 분할을 위한 전처리
x = train.drop('Activity', axis = 1)
y = train['Activity']

train_x, val_x, train_y, val_y = train_test_split(x, y, test_size = 0.2, stratify = y)
print(train_x.shape, train_y.shape)
print(val_x.shape, val_y.shape)
# Out:
# (4704, 561) (4704,)
# (1177, 561) (1177,)

# %% [markdown]
# #### 2) 모델링

# %%
#생성
RF = RandomForestClassifier(random_state = 42)

#학습
RF.fit(train_x, train_y)

#평가
y_pred = RF.predict(val_x)
print(confusion_matrix(val_y, y_pred))
print(classification_report(val_y, y_pred))
# Out:
# [[223   0   0   0   0   0]
#  [  0 195  10   0   0   1]
#  [  0  10 208   0   0   0]
#  [  0   0   0 199   1   0]
#  [  0   0   0   2 154   2]
#  [  0   0   0   1   3 168]]
#                     precision    recall  f1-score   support
#
#             LAYING       1.00      1.00      1.00       223
#            SITTING       0.95      0.95      0.95       206
#           STANDING       0.95      0.95      0.95       218
#            WALKING       0.99      0.99      0.99       200
# WALKING_DOWNSTAIRS       0.97      0.97      0.97       158
#   WALKING_UPSTAIRS       0.98      0.98      0.98       172
#
#           accuracy                           0.97      1177
#          macro avg       0.97      0.97      0.97      1177
#       weighted avg       0.97      0.97      0.97      1177

# %% [markdown]
# #### 3) 변수 중요도 추출

# %%
# 변수 중요도 추출(시각화로 나타내기)
plot_feature_importance(RF.feature_importances_, train_x.columns, topn = 50)
# Out:
#                        feature_name  feature_importance
# 0              angle(X,gravityMean)            0.041491
# 1            tGravityAcc-energy()-X            0.032015
# 2               tGravityAcc-min()-X            0.029053
# 3              tGravityAcc-mean()-X            0.027602
# 4               tGravityAcc-min()-Y            0.026607
# 5              tGravityAcc-mean()-Y            0.025180
# 6               tGravityAcc-max()-X            0.021150
# 7              angle(Y,gravityMean)            0.019669
# 8               tGravityAcc-max()-Y            0.018830
# 9         tGravityAcc-arCoeff()-Z,3            0.014187
# 10           tGravityAcc-energy()-Y            0.013356
# 11             tGravityAccMag-mad()            0.013096
# 12              tGravityAcc-max()-Z            0.012653
# 13            tBodyAccJerkMag-sma()            0.012426
# 14          tBodyAccJerk-energy()-X            0.012206
# 15  fBodyAccJerk-bandsEnergy()-1,16            0.011211
# ...

# %%
fi_df = plot_feature_importance(RF.feature_importances_, train_x.columns, result_only = True)
fi_df
# Out:
#                              feature_name  feature_importance
# 0                    angle(X,gravityMean)            0.041491
# 1                  tGravityAcc-energy()-X            0.032015
# 2                     tGravityAcc-min()-X            0.029053
# 3                    tGravityAcc-mean()-X            0.027602
# 4                     tGravityAcc-min()-Y            0.026607
# ..                                    ...                 ...
# 556  angle(tBodyAccJerkMean),gravityMean)            0.000086
# 557          fBodyAcc-bandsEnergy()-57,64            0.000086
# 558                  fBodyAccJerk-min()-Y            0.000084
# 559       fBodyGyro-bandsEnergy()-49,56.1            0.000078
# 560                      fBodyAcc-iqr()-Y            0.000050
#
# [561 rows x 2 columns]

# %% [markdown]
# ### (2) 중요도 기반 feature 분석

# %% [markdown]
# * **세부 요구사항**
#     - 상위 n, 하위 m 개의 변수를 선정
#     - 선정된 변수(feature)와 target 간의 관계를 kdeplot으로 그리기

# %% [markdown]
# #### 1) 상위 5, 하위 5개 변수 선정

# %%
# 중요도 상위 top 5
fi_df_top5 = plot_feature_importance(RF.feature_importances_, train_x.columns,result_only = True, topn = 5)
fi_df_top5
# Out:
#              feature_name  feature_importance
# 0    angle(X,gravityMean)            0.041491
# 1  tGravityAcc-energy()-X            0.032015
# 2     tGravityAcc-min()-X            0.029053
# 3    tGravityAcc-mean()-X            0.027602
# 4     tGravityAcc-min()-Y            0.026607

# %%
# 중요도 하위 top 5
fi_df_bot5 = plot_feature_importance(RF.feature_importances_, train_x.columns, result_only=True)
fi_df_bot5.tail()
# Out:
#                              feature_name  feature_importance
# 556  angle(tBodyAccJerkMean),gravityMean)            0.000086
# 557          fBodyAcc-bandsEnergy()-57,64            0.000086
# 558                  fBodyAccJerk-min()-Y            0.000084
# 559       fBodyGyro-bandsEnergy()-49,56.1            0.000078
# 560                      fBodyAcc-iqr()-Y            0.000050

# %% [markdown]
# #### 2) 상위 5개 변수에 대한 분석
#         - 위에서 나온 상위 5개의 변수를 선정해서 target과의 관계를 kdeplot으로 그려보세요!

# %%
features_top5 = list(fi_df_top5['feature_name'].values)
target = 'Activity'

for f in features_top5:
    plt.figure(figsize=(6,4))
    sns.kdeplot(data=train, x=f, hue=target, fill=True, common_norm=False, alpha=0.4)
    plt.xlabel(f)
    plt.show()

# %% [markdown]
# #### 3) 하위 5개 변수에 대한 분석
#         - 위에서 하위 5개의 변수를 선정해서 target과의 관계를 kdeplot으로 그려보세요!

# %%
features_bot5 = list(fi_df_bot5['feature_name'].tail().values)[::-1]
target = 'Activity'

for f in features_bot5:
    plt.figure(figsize=(6,4))
    sns.kdeplot(data=train, x=f, hue=target, fill=True, common_norm=False, alpha=0.4)
    plt.xlabel(f)
    plt.show()

# %% [markdown]
# ## 4.미션2 : 데이터 분석2

# %% [markdown]
# 다음의 case에 맞게 feature 및 feature 그룹 중요도를 기반으로 탐색적 데이터 분석을 수행하시오.
# * Target을 **정적/동적 행동**으로 구분
#     * 6개의 행동은 2개의 그룹(정적행동, 동적행동)으로 나뉩니다.
#     * 어떤 feature(혹은 feature 그룹)이 2개 class 그룹(정적행동, 동적행동)를 구분하는데 중요한지를 찾아보고 탐색해봅시다.

# %% [markdown]
# ### (1) 정적/동적 행동으로 구분하여 분석하기

# %% [markdown]
# * **세부 요구사항**
#     - Target인 Activity를 is_dynamic 변수로 변경하시오.
#         * 값 0 : STANDING, SITTING, LAYING
#         * 값 1 : WALKING, WALKING_UPSTAIRS, WALKING_DOWNSTAIRS
#     - is_dynamic을 예측하기 위한 기본 모델을 생성하시오.
#         * x, is_dynamic을 이용하여 train과 validation으로 데이터 분할
#         * 기본 모델링
#     - is_dynamic 을 구분하는데 중요한 변수 상위 5를 분석하시오.

# %% [markdown]
# #### 1) is_dynamic 추가

# %%
#is dynamic 변수를 추가하세요(값 0, 값 1 확인해서!)
group0 = ['STANDING', 'SITTING', 'LAYING']
group1 = ['WALKING', 'WALKING_UPSTAIRS', 'WALKING_DOWNSTAIRS']

train['is_dynamic'] = train['Activity'].apply(lambda x: 0 if x in group0 else 1)
train['is_dynamic']
# Out:
# 0       0
# 1       0
# 2       0
# 3       1
# 4       1
#        ..
# 5876    0
# 5877    1
# 5878    0
# 5879    1
# 5880    0
# Name: is_dynamic, Length: 5881, dtype: int64

# %%
train['is_dynamic'].value_counts()
# Out:
# is_dynamic
# 0    3234
# 1    2647
# Name: count, dtype: int64

# %% [markdown]
# #### 2) 기본모델 생성

# %%
#데이터 분할 진행(train:val = 8:2 혹은 7:3 권장)
x = train.drop(['Activity', 'is_dynamic'], axis = 1)
y = train['is_dynamic']

train_x, val_x, train_y, val_y = train_test_split(x, y, test_size = 0.2, stratify = y)
print(train_x.shape, train_y.shape)
print(val_x.shape, val_y.shape)
# Out:
# (4704, 561) (4704,)
# (1177, 561) (1177,)

# %%
#RandomForestClassifier로 모델링 진행
RF = RandomForestClassifier(random_state = 42)

RF.fit(train_x, train_y)

y_pred = RF.predict(val_x)

print(confusion_matrix(val_y, y_pred))
print(classification_report(val_y, y_pred))
# Out:
# [[646   1]
#  [  0 530]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       647
#            1       1.00      1.00      1.00       530
#
#     accuracy                           1.00      1177
#    macro avg       1.00      1.00      1.00      1177
# weighted avg       1.00      1.00      1.00      1177

# %% [markdown]
# #### 3) 변수중요도 상위 5개 분석

# %%
fi_df_dy = plot_feature_importance(RF.feature_importances_, train_x.columns, result_only = True)
fi_df_dy
# Out:
#                         feature_name  feature_importance
# 0               fBodyAccJerk-mad()-X            0.069812
# 1            tBodyAccJerk-energy()-X            0.050029
# 2    fBodyAccJerk-bandsEnergy()-1,16            0.040068
# 3              tBodyAccJerkMag-sma()            0.040060
# 4               tBodyAccJerk-mad()-X            0.039966
# ..                               ...                 ...
# 556                tBodyGyro-min()-X            0.000000
# 557                tBodyGyro-max()-Z            0.000000
# 558                tBodyGyro-max()-Y            0.000000
# 559                tBodyGyro-max()-X            0.000000
# 560             tBodyAccJerk-mad()-Z            0.000000
#
# [561 rows x 2 columns]

# %%
# is_dynamic 을 구분하는데 중요한 변수 상위 5를 분석!
fi_df_dy_top5 = plot_feature_importance(RF.feature_importances_, train_x.columns,result_only = True, topn = 5)
fi_df_dy_top5
# Out:
#                       feature_name  feature_importance
# 0             fBodyAccJerk-mad()-X            0.069812
# 1          tBodyAccJerk-energy()-X            0.050029
# 2  fBodyAccJerk-bandsEnergy()-1,16            0.040068
# 3            tBodyAccJerkMag-sma()            0.040060
# 4             tBodyAccJerk-mad()-X            0.039966

# %% [markdown]
# * 미션1에서 했던 것 처럼 상위 5개의 변수 데이터를 탐색해보기!

# %%
features_dy_top5 = list(fi_df_dy_top5['feature_name'].values)
target = 'is_dynamic'

for f in features_dy_top5:
    plt.figure(figsize=(6,4))
    sns.kdeplot(data=train, x=f, hue=target, fill=True, common_norm=False, alpha=0.4)
    plt.xlabel(f)
    plt.show()

# %% [markdown]
# ## 5.특성 중요도 저장하기

# %% [markdown]
# * **세부 요구사항**
#     - 지금까지 변수 중요도를 다양한 관점에서 뽑고 분석을 해 보았습니다.
#         - 관점1 : 6개 행동 구분
#         - 관점2 : 동적, 정적 행동 구분
#     - 모든 관점의 변수 중요도를 하나로 합친 후 저장
#         - merge를 이용하여 features와 합칩니다.
#         - joblib 패키지의 dump를 이용하여 결과를 저장합니다.

# %% [markdown]
# ### (1) 하나로 합치기
# * 합치기 위해서는 중요도 결과에서 feature_importance 칼럼 이름을 수정해야 합니다.
# * pd.merge를 이용해서 하나씩 합치는 작업을 반복 합니다.

# %% [markdown]
# #### 1) 이름변경

# %%
# tip : rename을 써서 칼럼 이름 수정을 해야합니다!
fi_df.rename(columns = {'feature_importance' : 'feature_importance_6'}, inplace = True)
fi_df_dy.rename(columns = {'feature_importance' : 'feature_importance_2'}, inplace = True)

# %% [markdown]
# #### 2) 합치기

# %%
# merge 해서 2개를 합치는 작업하기
df_f = pd.merge(features, fi_df, on = 'feature_name')
df_f2 = pd.merge(df_f, fi_df_dy, on = 'feature_name')

# %%
df_f2
# Out:
#        sensor                agg         axis  \
# 0    tBodyAcc             mean()            X
# 1    tBodyAcc             mean()            Y
# 2    tBodyAcc             mean()            Z
# 3    tBodyAcc              std()            X
# 4    tBodyAcc              std()            Y
# ..        ...                ...          ...
# 556     angle      tBodyGyroMean  gravityMean
# 557     angle  tBodyGyroJerkMean  gravityMean
# 558     angle                  X  gravityMean
# 559     angle                  Y  gravityMean
# 560     angle                  Z  gravityMean
#
#                              feature_name  feature_importance_6  \
# 0                       tBodyAcc-mean()-X              0.000307
# 1                       tBodyAcc-mean()-Y              0.000225
# 2                       tBodyAcc-mean()-Z              0.000173
# 3                        tBodyAcc-std()-X              0.004511
# 4                        tBodyAcc-std()-Y              0.000516
# ...

# %% [markdown]
# ### (2) 저장하기
# * joblib.dump를 이용하시오.
# * 저장할 파일의 확장자는 보통 .pkl 입니다.

# %%
# joblib.dump 이용해서 colab에 .pkl 파일에 저장하기(tip: path + '파일 이름.pkl')
joblib.dump(df_f2, path + 'feature_imp.pkl')
# Out:
# ['/content/drive/MyDrive/project1_2/feature_imp.pkl']

# %% [markdown]
# #### 고생하셨습니다! 이제 기본 모델링을 해봅시다.
